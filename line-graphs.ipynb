# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("recent-grads.csv")

# %%
data.head()
# Out:
#    rank  major_code                                      major    total  \
# 0     1        2419                      petroleum engineering   2339.0
# 1     2        2416             mining and mineral engineering    756.0
# 2     3        2415                  metallurgical engineering    856.0
# 3     4        2417  naval architecture and marine engineering   1258.0
# 4     5        2405                       chemical engineering  32260.0
#
#        men    women major_category  sharewomen  sample_size  employed  ...  \
# 0   2057.0    282.0    engineering    0.120564           36      1976  ...
# 1    679.0     77.0    engineering    0.101852            7       640  ...
# 2    725.0    131.0    engineering    0.153037            3       648  ...
# 3   1123.0    135.0    engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    engineering    0.341631          289     25694  ...
#
#    unemployed  unemployment_rate  median  p25th   p75th  college_jobs  \
# ...

# %%
data = data.iloc[:,:-1]

# %%
data = data.iloc[:, :-1]

# %%
data.head()
# Out:
#    rank  major_code                                      major    total  \
# 0     1        2419                      petroleum engineering   2339.0
# 1     2        2416             mining and mineral engineering    756.0
# 2     3        2415                  metallurgical engineering    856.0
# 3     4        2417  naval architecture and marine engineering   1258.0
# 4     5        2405                       chemical engineering  32260.0
#
#        men    women major_category  sharewomen  sample_size  employed  \
# 0   2057.0    282.0    engineering    0.120564           36      1976
# 1    679.0     77.0    engineering    0.101852            7       640
# 2    725.0    131.0    engineering    0.153037            3       648
# 3   1123.0    135.0    engineering    0.107313           16       758
# 4  21239.0  11021.0    engineering    0.341631          289     25694
#
#    full_time  part_time  full_time_year_round  unemployed  unemployment_rate  \
# ...

# %%
data.tail()
# Out:
#      rank  major_code                   major   total     men   women  \
# 166   169        3609                 zoology  8409.0  3050.0  5359.0
# 167   170        5201  educational psychology  2854.0   522.0  2332.0
# 168   171        5202     clinical psychology  2838.0   568.0  2270.0
# 169   172        5203   counseling psychology  4626.0   931.0  3695.0
# 170   173        3501         library science  1098.0   134.0   964.0
#
#                major_category  sharewomen  sample_size  employed  full_time  \
# 166    biology & life science    0.637293           47      6259       5043
# 167  psychology & social work    0.817099            7      2125       1848
# 168  psychology & social work    0.799859           13      2101       1724
# 169  psychology & social work    0.798746           21      3777       3154
# 170                 education    0.877960            2       742        593
#
#      part_time  full_time_year_round  unemployed  unemployment_rate  median  \
# ...

# %%
data.plot.line(x="rank",y=["p25th","median","p75th"])
plt.title("Stats across Rank")
plt.ylabel("Number of Graduates")
plt.show()

# %%
data.plot.line(x="rank",y=["total"])
plt.title("Total Graduates vs Rank")
plt.ylabel("Number of graduates")
plt.show()
